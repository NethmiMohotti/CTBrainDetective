# %% [markdown]
# <a href="https://colab.research.google.com/github/NethmiMohotti/CTBrainDetective/blob/Training/Training/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# !pip install pyyaml -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 6.8 MB/s eta 0:00:00

# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.0.230
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://github.com/ultralytics/ultralytics
# Author: Ultralytics
# Author-email: hello@ultralytics.com
# License: AGPL-3.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:

# %%
import torch
torch.__version__
# Out:
# '2.1.0+cu121'

# %%
from ultralytics import YOLO
##training model
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 304MB/s]

# %%
# !touch data.yaml

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model.train(data ="/content/data.yaml" , epochs = 25)
# Out:
# Ultralytics YOLOv8.0.230 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Best performing model/ fine tune model

# %%
from google.colab import files
files.download("/content/runs")

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install aspose-words

# %%
ls -l
# Out:
# total 57300
# -rw-r--r-- 1 root root      231 Dec 27 18:23 data.yaml
# drwx------ 6 root root     4096 Dec 27 18:18 drive/
# drwxr-xr-x 3 root root     4096 Dec 27 18:21 runs/
# drwxr-xr-x 1 root root     4096 Dec 19 14:20 sample_data/
# -rw-r--r-- 1 root root 52117635 Dec 27 18:19 yolov8m.pt
# -rw-r--r-- 1 root root  6534387 Dec 27 18:23 yolov8n.pt

# %%
! zip runs.zip runs/

# %%
infer = YOLO ("/content/runs/detect/train3/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/FYP/Development/CT_Brain_hemorrhage/train/images",  save = True, save_txt = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/2496 /content/drive/MyDrive/FYP/Development/CT_Brain_hemorrhage/train/images/100135_png_jpg.rf.489b45ca41f0dd68d66f8f5ca1866633.jpg: 640x640 3 Subdurals, 37.9ms
# image 2/2496 /content/drive/MyDrive/FYP/Development/CT_Brain_hemorrhage/train/images/100135_png_jpg.rf.6c7b41f2ab7f37705dba1f2c6b042332.jpg: 640x640 3 Subdurals, 37.2ms
# ...
